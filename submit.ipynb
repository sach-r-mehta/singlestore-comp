# %% [markdown]
# Silent data streams flow,
# Vectors map the mind's expanse,
# AI dreams awake.

# %%
               +-------------+
               |   Input     |
               +------+------+
                      |
                      v
            +---------+----------+
            |  Preprocessing     |
            +---------+----------+
                      |
                      v
  +---------+   +-----+-----+      +--------------+
  | External|<->|   LLM     |<---->| Vector       |
  | Data    |   +-----+-----+      | Database     |
  +---------+         |            +------+-------+
                      v                   |
           +----------+-----------+      |
           |     Task at Hand     |<-----+
           +----------+-----------+
                      |
                      v
            +---------+----------+
            |   Decision Making  |
            +---------+----------+
                      |
                      v
               +------+------+
               |   Output    |
               +-------------+
